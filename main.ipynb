# %%
#importing Libraries
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
from scipy import stats
import tensorflow as tf
import seaborn as sns
from pylab import rcParams
from sklearn.model_selection import train_test_split
from keras.models import Model, load_model
from keras.layers import Input, Dense
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import regularizers
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (confusion_matrix, precision_recall_curve, auc,
                             roc_curve, recall_score, classification_report, f1_score,
                             precision_recall_fscore_support)

# %matplotlib inline

sns.set(style='whitegrid', palette='muted', font_scale=1.5)

rcParams['figure.figsize'] = 14, 8

RANDOM_SEED = 42
LABELS = ["Normal", "Fraud"]

# %% [markdown]
# Data Analysis

# %%
df = pd.read_csv("data.csv")

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.isnull().values.sum()
# Out:
# 0

# %%
count_classes = pd.value_counts(df['Class'], sort = True)
count_classes.plot(kind = 'bar', rot=0)
plt.title("Transaction class distribution")
plt.xticks(range(2), LABELS)
plt.xlabel("Class")
plt.ylabel("Frequency");

# %%
frauds = df[df.Class == 1]
normal = df[df.Class == 0]

# %%
frauds.shape
# Out:
# (492, 31)

# %%
normal.shape
# Out:
# (284315, 31)

# %%
frauds.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
normal.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
f.suptitle('Amount per transaction by class')

bins = 50

ax1.hist(frauds.Amount, bins = bins)
ax1.set_title('Fraud')

ax2.hist(normal.Amount, bins = bins)
ax2.set_title('Normal')

plt.xlabel('Amount ($)')
plt.ylabel('Number of Transactions')
plt.xlim((0, 20000))
plt.yscale('log')
plt.show();

# %% [markdown]
# ##### Do fraudulent transactions occur more often during certain time?

# %%
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
f.suptitle('Time of transaction vs Amount by class')

ax1.scatter(frauds.Time, frauds.Amount)
ax1.set_title('Fraud')

ax2.scatter(normal.Time, normal.Amount)
ax2.set_title('Normal')

plt.xlabel('Time (in Seconds)')
plt.ylabel('Amount')
plt.show()

# %% [markdown]
# Preparing the data

# %%
data = df.drop(['Time'], axis=1)

data['Amount'] = StandardScaler().fit_transform(data['Amount'].values.reshape(-1, 1))

# %%
X_train, X_test = train_test_split(data, test_size=0.2, random_state=RANDOM_SEED)
X_train = X_train[X_train.Class == 0]
X_train = X_train.drop(['Class'], axis=1)

y_test = X_test['Class']
X_test = X_test.drop(['Class'], axis=1)

X_train = X_train.values
X_test = X_test.values

# %%
X_train.shape
# Out:
# (227451, 29)

# %% [markdown]
# Building the model

# %%
input_dim = X_train.shape[1]
encoding_dim = 14

# %%
input_layer = Input(shape=(input_dim, ))

encoder = Dense(encoding_dim, activation="tanh", 
                activity_regularizer=regularizers.l1(10e-5))(input_layer)
encoder = Dense(int(encoding_dim / 2), activation="relu")(encoder)

decoder = Dense(int(encoding_dim / 2), activation='tanh')(encoder)
decoder = Dense(input_dim, activation='relu')(decoder)

autoencoder = Model(inputs=input_layer, outputs=decoder)

# %%
nb_epoch = 100
batch_size = 32

autoencoder.compile(optimizer='adam', 
                    loss='mean_squared_error', 
                    metrics=['accuracy'])

checkpointer = ModelCheckpoint(filepath="model.h5",
                               verbose=0,
                               save_best_only=True)
tensorboard = TensorBoard(log_dir='./logs',
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)

history = autoencoder.fit(X_train, X_train,
                    epochs=nb_epoch,
                    batch_size=batch_size,
                    shuffle=True,
                    validation_data=(X_test, X_test),
                    verbose=1,
                    callbacks=[checkpointer, tensorboard]).history
# Out:
# Epoch 1/100
# 7108/7108 [==============================] - 14s 2ms/step - loss: 0.8173 - accuracy: 0.5676 - val_loss: 0.7825 - val_accuracy: 0.6676
# Epoch 2/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7379 - accuracy: 0.6815 - val_loss: 0.7609 - val_accuracy: 0.6950
# Epoch 3/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7238 - accuracy: 0.6963 - val_loss: 0.7518 - val_accuracy: 0.7015
# Epoch 4/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7179 - accuracy: 0.7044 - val_loss: 0.7497 - val_accuracy: 0.7027
# Epoch 5/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.7146 - accuracy: 0.7069 - val_loss: 0.7475 - val_accuracy: 0.7083
# Epoch 6/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7129 - accuracy: 0.7071 - val_loss: 0.7479 - val_accuracy: 0.7117
# Epoch 7/100
# 7108/7108 [==============================] - 14s 2ms/step - loss: 0.7117 - accuracy: 0.7074 - val_loss: 0.7451 - val_accuracy: 0.7112
# Epoch 8/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.7110 - accuracy: 0.7069 - val_loss: 0.7457 - val_accuracy: 0.7079
# Epoch 9/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.7100 - accuracy: 0.7061 - val_loss: 0.7435 - val_accuracy: 0.7067
# Epoch 10/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.7095 - accuracy: 0.7068 - val_loss: 0.7456 - val_accuracy: 0.7051
# Epoch 11/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.7083 - accuracy: 0.7068 - val_loss: 0.7427 - val_accuracy: 0.7079
# Epoch 12/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.7075 - accuracy: 0.7058 - val_loss: 0.7420 - val_accuracy: 0.7152
# Epoch 13/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.7065 - accuracy: 0.7050 - val_loss: 0.7409 - val_accuracy: 0.7087
# Epoch 14/100
# 7108/7108 [==============================] - 14s 2ms/step - loss: 0.7053 - accuracy: 0.7044 - val_loss: 0.7391 - val_accuracy: 0.7110
# Epoch 15/100
# 7108/7108 [==============================] - 14s 2ms/step - loss: 0.7041 - accuracy: 0.7055 - val_loss: 0.7389 - val_accuracy: 0.7098
# Epoch 16/100
# 7108/7108 [==============================] - 14s 2ms/step - loss: 0.7040 - accuracy: 0.7065 - val_loss: 0.7389 - val_accuracy: 0.7078
# Epoch 17/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7026 - accuracy: 0.7081 - val_loss: 0.7371 - val_accuracy: 0.7078
# Epoch 18/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7025 - accuracy: 0.7088 - val_loss: 0.7385 - val_accuracy: 0.7026
# Epoch 19/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7026 - accuracy: 0.7088 - val_loss: 0.7360 - val_accuracy: 0.7141
# Epoch 20/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7018 - accuracy: 0.7094 - val_loss: 0.7414 - val_accuracy: 0.7091
# Epoch 21/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7017 - accuracy: 0.7087 - val_loss: 0.7382 - val_accuracy: 0.7131
# Epoch 22/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7017 - accuracy: 0.7097 - val_loss: 0.7370 - val_accuracy: 0.7125
# Epoch 23/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7013 - accuracy: 0.7088 - val_loss: 0.7369 - val_accuracy: 0.7071
# Epoch 24/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7013 - accuracy: 0.7089 - val_loss: 0.7363 - val_accuracy: 0.7106
# Epoch 25/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7013 - accuracy: 0.7079 - val_loss: 0.7362 - val_accuracy: 0.7133
# Epoch 26/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7009 - accuracy: 0.7089 - val_loss: 0.7370 - val_accuracy: 0.7087
# Epoch 27/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7009 - accuracy: 0.7085 - val_loss: 0.7357 - val_accuracy: 0.7132
# Epoch 28/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7012 - accuracy: 0.7088 - val_loss: 0.7376 - val_accuracy: 0.7084
# Epoch 29/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7007 - accuracy: 0.7086 - val_loss: 0.7366 - val_accuracy: 0.7129
# Epoch 30/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7005 - accuracy: 0.7082 - val_loss: 0.7351 - val_accuracy: 0.7102
# Epoch 31/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7006 - accuracy: 0.7080 - val_loss: 0.7350 - val_accuracy: 0.7114
# Epoch 32/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7008 - accuracy: 0.7077 - val_loss: 0.7353 - val_accuracy: 0.7173
# Epoch 33/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7003 - accuracy: 0.7086 - val_loss: 0.7397 - val_accuracy: 0.7112
# Epoch 34/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7006 - accuracy: 0.7076 - val_loss: 0.7471 - val_accuracy: 0.6924
# Epoch 35/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7001 - accuracy: 0.7087 - val_loss: 0.7353 - val_accuracy: 0.7144
# Epoch 36/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7013 - accuracy: 0.7070 - val_loss: 0.7369 - val_accuracy: 0.7114
# Epoch 37/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.7006 - accuracy: 0.7073 - val_loss: 0.7370 - val_accuracy: 0.7040
# Epoch 38/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7003 - accuracy: 0.7072 - val_loss: 0.7440 - val_accuracy: 0.6965
# Epoch 39/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.7004 - accuracy: 0.7074 - val_loss: 0.7359 - val_accuracy: 0.7046
# Epoch 40/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6999 - accuracy: 0.7075 - val_loss: 0.7361 - val_accuracy: 0.7104
# Epoch 41/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7004 - accuracy: 0.7073 - val_loss: 0.7353 - val_accuracy: 0.7076
# Epoch 42/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.7009 - accuracy: 0.7075 - val_loss: 0.7356 - val_accuracy: 0.7085
# Epoch 43/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6998 - accuracy: 0.7078 - val_loss: 0.7354 - val_accuracy: 0.7112
# Epoch 44/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.7002 - accuracy: 0.7067 - val_loss: 0.7378 - val_accuracy: 0.7012
# Epoch 45/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6999 - accuracy: 0.7066 - val_loss: 0.7439 - val_accuracy: 0.7091
# Epoch 46/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7000 - accuracy: 0.7062 - val_loss: 0.7346 - val_accuracy: 0.7071
# Epoch 47/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.7000 - accuracy: 0.7065 - val_loss: 0.7374 - val_accuracy: 0.7068
# Epoch 48/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6997 - accuracy: 0.7070 - val_loss: 0.7350 - val_accuracy: 0.7134
# Epoch 49/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7000 - accuracy: 0.7065 - val_loss: 0.7352 - val_accuracy: 0.7069
# Epoch 50/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.7000 - accuracy: 0.7053 - val_loss: 0.7350 - val_accuracy: 0.7131
# Epoch 51/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6998 - accuracy: 0.7059 - val_loss: 0.7352 - val_accuracy: 0.7069
# Epoch 52/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6998 - accuracy: 0.7063 - val_loss: 0.7342 - val_accuracy: 0.7160
# Epoch 53/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6994 - accuracy: 0.7068 - val_loss: 0.7376 - val_accuracy: 0.7015
# Epoch 54/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.7001 - accuracy: 0.7056 - val_loss: 0.7343 - val_accuracy: 0.7088
# Epoch 55/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.7000 - accuracy: 0.7054 - val_loss: 0.7353 - val_accuracy: 0.7104
# Epoch 56/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6996 - accuracy: 0.7062 - val_loss: 0.7373 - val_accuracy: 0.7113
# Epoch 57/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6999 - accuracy: 0.7064 - val_loss: 0.7362 - val_accuracy: 0.7106
# Epoch 58/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6999 - accuracy: 0.7048 - val_loss: 0.7373 - val_accuracy: 0.7091
# Epoch 59/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6997 - accuracy: 0.7054 - val_loss: 0.7350 - val_accuracy: 0.7064
# Epoch 60/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6996 - accuracy: 0.7047 - val_loss: 0.7365 - val_accuracy: 0.6973
# Epoch 61/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6993 - accuracy: 0.7046 - val_loss: 0.7362 - val_accuracy: 0.7089
# Epoch 62/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6996 - accuracy: 0.7044 - val_loss: 0.7355 - val_accuracy: 0.7112
# Epoch 63/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6994 - accuracy: 0.7055 - val_loss: 0.7350 - val_accuracy: 0.7052
# Epoch 64/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6995 - accuracy: 0.7062 - val_loss: 0.7363 - val_accuracy: 0.7025
# Epoch 65/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6999 - accuracy: 0.7049 - val_loss: 0.7351 - val_accuracy: 0.7003
# Epoch 66/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.7000 - accuracy: 0.7054 - val_loss: 0.7344 - val_accuracy: 0.7076
# Epoch 67/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6994 - accuracy: 0.7055 - val_loss: 0.7373 - val_accuracy: 0.7129
# Epoch 68/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6998 - accuracy: 0.7053 - val_loss: 0.7353 - val_accuracy: 0.7057
# Epoch 69/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.7000 - accuracy: 0.7053 - val_loss: 0.7363 - val_accuracy: 0.7119
# Epoch 70/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6997 - accuracy: 0.7055 - val_loss: 0.7357 - val_accuracy: 0.7039
# Epoch 71/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6997 - accuracy: 0.7058 - val_loss: 0.7352 - val_accuracy: 0.7135
# Epoch 72/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6994 - accuracy: 0.7045 - val_loss: 0.7348 - val_accuracy: 0.7118
# Epoch 73/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6992 - accuracy: 0.7048 - val_loss: 0.7347 - val_accuracy: 0.7102
# Epoch 74/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6992 - accuracy: 0.7043 - val_loss: 0.7400 - val_accuracy: 0.6985
# Epoch 75/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6994 - accuracy: 0.7049 - val_loss: 0.7387 - val_accuracy: 0.7133
# Epoch 76/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6993 - accuracy: 0.7055 - val_loss: 0.7349 - val_accuracy: 0.7082
# Epoch 77/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6994 - accuracy: 0.7043 - val_loss: 0.7359 - val_accuracy: 0.7105
# Epoch 78/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6991 - accuracy: 0.7048 - val_loss: 0.7362 - val_accuracy: 0.7044
# Epoch 79/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6994 - accuracy: 0.7043 - val_loss: 0.7352 - val_accuracy: 0.7066
# Epoch 80/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6997 - accuracy: 0.7040 - val_loss: 0.7354 - val_accuracy: 0.7019
# Epoch 81/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6993 - accuracy: 0.7050 - val_loss: 0.7361 - val_accuracy: 0.7089
# Epoch 82/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6990 - accuracy: 0.7050 - val_loss: 0.7344 - val_accuracy: 0.7089
# Epoch 83/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6987 - accuracy: 0.7053 - val_loss: 0.7348 - val_accuracy: 0.7131
# Epoch 84/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6996 - accuracy: 0.7039 - val_loss: 0.7346 - val_accuracy: 0.7049
# Epoch 85/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6994 - accuracy: 0.7046 - val_loss: 0.7357 - val_accuracy: 0.7073
# Epoch 86/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6991 - accuracy: 0.7047 - val_loss: 0.7363 - val_accuracy: 0.7109
# Epoch 87/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6991 - accuracy: 0.7049 - val_loss: 0.7343 - val_accuracy: 0.7116
# Epoch 88/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6989 - accuracy: 0.7051 - val_loss: 0.7369 - val_accuracy: 0.6998
# Epoch 89/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6991 - accuracy: 0.7052 - val_loss: 0.7351 - val_accuracy: 0.7150
# Epoch 90/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6991 - accuracy: 0.7036 - val_loss: 0.7340 - val_accuracy: 0.7098
# Epoch 91/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6992 - accuracy: 0.7052 - val_loss: 0.7353 - val_accuracy: 0.7039
# Epoch 92/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6991 - accuracy: 0.7052 - val_loss: 0.7368 - val_accuracy: 0.7059
# Epoch 93/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6990 - accuracy: 0.7046 - val_loss: 0.7331 - val_accuracy: 0.7125
# Epoch 94/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6993 - accuracy: 0.7052 - val_loss: 0.7361 - val_accuracy: 0.7095
# Epoch 95/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6996 - accuracy: 0.7040 - val_loss: 0.7380 - val_accuracy: 0.7033
# Epoch 96/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6987 - accuracy: 0.7055 - val_loss: 0.7355 - val_accuracy: 0.7086
# Epoch 97/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6988 - accuracy: 0.7055 - val_loss: 0.7353 - val_accuracy: 0.7128
# Epoch 98/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6994 - accuracy: 0.7043 - val_loss: 0.7351 - val_accuracy: 0.7090
# Epoch 99/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6986 - accuracy: 0.7053 - val_loss: 0.7383 - val_accuracy: 0.7066
# Epoch 100/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6990 - accuracy: 0.7038 - val_loss: 0.7362 - val_accuracy: 0.7078

# %%
autoencoder = load_model('model.h5')

# %% [markdown]
# Evaluation

# %%
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right');

# %%
predictions = autoencoder.predict(X_test)
# Out:
# 1781/1781 [==============================] - 2s 900us/step

# %%
mse = np.mean(np.power(X_test - predictions, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse,
                        'true_class': y_test})

# %%
error_df.describe()
# Out:
#        reconstruction_error    true_class
# count          56962.000000  56962.000000
# mean               0.732234      0.001720
# std                3.397583      0.041443
# min                0.042504      0.000000
# 25%                0.232112      0.000000
# 50%                0.387768      0.000000
# 75%                0.621543      0.000000
# max              258.528681      1.000000

# %% [markdown]
# Reconstruction error without fraud

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
normal_error_df = error_df[(error_df['true_class']== 0) & (error_df['reconstruction_error'] < 10)]
_ = ax.hist(normal_error_df.reconstruction_error.values, bins=10)

# %%
fpr, tpr, thresholds = roc_curve(error_df.true_class, error_df.reconstruction_error)
roc_auc = auc(fpr, tpr)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, label='AUC = %0.4f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.001, 1])
plt.ylim([0, 1.001])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
precision, recall, th = precision_recall_curve(error_df.true_class, error_df.reconstruction_error)
plt.plot(recall, precision, 'b', label='Precision-Recall curve')
plt.title('Recall vs Precision')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()

# %%
plt.plot(th, precision[1:], 'b', label='Threshold-Precision curve')
plt.title('Precision for different threshold values')
plt.xlabel('Threshold')
plt.ylabel('Precision')
plt.show()

# %%
plt.plot(th, recall[1:], 'b', label='Threshold-Recall curve')
plt.title('Recall for different threshold values')
plt.xlabel('Reconstruction error')
plt.ylabel('Recall')
plt.show()

# %%
threshold = 2.9

# %%
groups = error_df.groupby('true_class')
fig, ax = plt.subplots()
for name, group in groups:
    ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Fraud" if name == 1 else "Normal")
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

# %%
y_pred = [1 if e > threshold else 0 for e in error_df.reconstruction_error.values]
conf_matrix = confusion_matrix(error_df.true_class, y_pred)
plt.figure(figsize=(12, 12))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

# %%
# %tensorboard
# Out:
# UsageError: Line magic function `%tensorboard` not found.
